# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import csv
import numpy as np
from numba import jit
import os


def plot_grid(grid, img_id):
    print(f"Plotting grid for {img_id}")
    grid = get_wb_borders(grid)
    fig, ax = plt.subplots()
    ax.imshow(grid, cmap="gray", interpolation="nearest")
    ax.axis("off")  # Hide the axes
    plt.subplots_adjust(left=0, right=1, top=1, bottom=0)  # Remove padding
    filename = f"output/{img_id}.png"
    fig.savefig(filename, bbox_inches="tight", pad_inches=0)
    plt.close(fig)


def save_grid(grid, img_id, size):
    grid = get_wb_borders(grid)
    directory = f"output{size}"
    if not os.path.exists(directory):
        os.makedirs(directory)
    with open(f"output{size}/{img_id}.csv", mode="a", newline="") as file:
        writer = csv.writer(file)
        for i in range(grid.shape[0]):
            writer.writerow(grid[i])


@jit(nopython=True)
def get_wb_borders(grid):
    size = grid.shape[0]
    wb_array = np.zeros_like(grid, dtype=np.uint8)

    for x in range(1, size - 1):
        for y in range(1, size - 1):
            current_value = grid[x, y]
            if (
                grid[x - 1, y] != current_value
                or grid[x + 1, y] != current_value
                or grid[x, y - 1] != current_value
                or grid[x, y + 1] != current_value
            ):
                wb_array[x, y] = 1

    return wb_array


def plot_combined(temperature, grid, filename):
    grid = get_wb_borders(grid)

    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Plot temperature
    axs[0].imshow(temperature, cmap="hot", interpolation="nearest")
    axs[0].set_title("Temperature")
    fig.colorbar(axs[0].images[0], ax=axs[0])

    # Create a unique color map for the grid
    unique_values = np.unique(grid)
    num_unique_values = len(unique_values)
    colors = plt.cm.get_cmap(
        "tab20", num_unique_values
    ).colors  # Generate a color for each unique value
    cmap = ListedColormap(colors)

    # Plot grid
    cax = axs[1].imshow(grid, cmap=cmap, interpolation="nearest")
    axs[1].set_title("Grid")

    # Create a colorbar with the correct labels
    cbar = fig.colorbar(cax, ax=axs[1], ticks=unique_values)
    cbar.ax.set_yticklabels(
        [str(val) for val in unique_values]
    )  # Set the ticks to be the unique values

    # Save the combined plot as a PNG file
    # plt.savefig(filename)
    plt.show()

# %%
import numpy as np
from numba import jit
import csv
import uuid


@jit(nopython=True)
def random_grain(prob, max_val):
    return np.random.randint(1, max_val + 1) if np.random.random() < prob else 0


@jit(nopython=True)
def update_grid_numba(grid, temperature, dt):
    hasLiquid = False
    new_grid = grid.copy()
    size = grid.shape[0]
    for x in range(1, size - 1):
        for y in range(1, size - 1):
            if temperature[x, y] > 0.80:
                new_grid[x, y] = 0
                continue
            if grid[x, y] == 0:
                hasLiquid = True
                prob = (1 - temperature[x, y] / 0.8) / 500
                if np.random.random() < prob:
                    new_grid[x, y] = np.random.randint(1, 20)
                neighbors = grid[x - 1 : x + 2, y - 1 : y + 2].ravel()
                non_zero_neighbors = neighbors[neighbors != 0]
                if len(non_zero_neighbors) > 0 and np.random.random() > (
                    temperature[x, y] / 0.8
                ):
                    new_grid[x, y] = np.random.choice(non_zero_neighbors)
    return new_grid, hasLiquid


@jit(nopython=True)
def update_temp_2d_numba(u, dt, dx, dy, k):
    u_new = u.copy()
    nx, ny = u.shape

    y1 = u_new.shape[1] - 1
    for x1 in range(u_new.shape[0]):
        u_new[x1, y1] = min(u_new[x1, y1 - 1], u_new[x1, y1 - 2])
        u_new[x1, 0] = min(u_new[x1, 1], u_new[x1, 2])
    x2 = u_new.shape[0] - 1
    for y2 in range(u_new.shape[1]):
        u_new[x2, y2] = min(u_new[x2 - 1, y2], u_new[x2 - 2, y2])
        u_new[0, y2] = min(u_new[1, y2], u_new[2, y2])

    for i in range(1, nx - 1):
        for j in range(1, ny - 1):
            u_new[i, j] = u[i, j] + k * dt * (
                (u[i + 1, j] - 2 * u[i, j] + u[i - 1, j]) / dx**2
                + (u[i, j + 1] - 2 * u[i, j] + u[i, j - 1]) / dy**2
            )
    return u_new


@jit(nopython=True)
def apply_heat_numba(u, x, y, r, initial_temp, air_temp):
    u_new = u.copy()
    nx, ny = u.shape
    for i in range(1, nx - 1):
        for j in range(1, ny - 1):
            dist_sq = (i - x) ** 2 + (j - y) ** 2
            if dist_sq <= r**2:
                u_new[i, j] = initial_temp - (initial_temp - air_temp) * (
                    dist_sq / (r * r)
                )
    return u_new


def mainLoop(img_id, size, initX, initY):
    points = [(initX, initY, 0)]
    dx, dy = 0.1, 0.1
    dt = 0.01
    time = 0
    end_time = 1.7
    initial_temp = 2
    air_temp = 0.01
    k = 1

    if dt > 1 / (2 * k * (1 / dx / dx + 1 / dy / dy)):
        dt = 1 / (2 * k * (1 / dx / dx + 1 / dy / dy))
        print(f"Adjusted dt for stability. New value dt={dt}")

    nx = ny = size
    u = air_temp * np.ones((nx + 2, ny + 2))
    u[0, :] = u[:, 0] = u[-1, :] = u[:, -1] = air_temp

    grid = np.zeros((size * 4 + 2, size * 4 + 2), dtype=np.uint8)
    for i in range(1, size * 4 + 1):
        for j in range(1, size * 4 + 1):
            grid[i, j] = random_grain(1 / 500, 19)

    n = 0
    dtCA = 0.01
    timeCA = 0
    timeHeat = -1

    hasLiquid = True

    while hasLiquid:
        time += dt
        n += 1
        while points and points[0][2] < time:
            lastHeatX, lastHeatY, _ = points.pop(0)
            timeHeat = time
            u = apply_heat_numba(
                u, lastHeatX + 1, lastHeatY + 1, size // 2, initial_temp, air_temp
            )
            grid, hasLiquid = update_grid_numba(
                grid, np.repeat(np.repeat(u, 4, axis=0), 4, axis=1), dt
            )

        if time - timeCA > dtCA:
            timeCA += dtCA
            grid, hasLiquid = update_grid_numba(
                grid, np.repeat(np.repeat(u, 4, axis=0), 4, axis=1), dt
            )

        # if n % 10 == 0:
        # print(f"Simulated for time {time:.2f}")

        u = update_temp_2d_numba(u, dt, dx, dy, k)

    # print(f"Simulation completed for {img_id}")

    # plot_grid(grid, img_id)
    # plot_combined(u, grid, f"output/{img_id}.png")
    save_grid(grid, img_id, size)


def main():
    size = 32
    samples = []

    genlen = 5000
    initXs = np.random.randint(0, size, genlen)
    initYs = np.random.randint(0, size, genlen)
    img_ids = [uuid.uuid4() for _ in range(genlen)]

    for i in range(genlen):
        initX = initXs[i]
        initY = initYs[i]
        img_id = img_ids[i]
        samples.append([initX, initY, img_id])
        mainLoop(img_id, size, initX, initY)
        print(f"Simulation completed for {i}")

    with open(f"input{size}.csv", mode="a", newline="") as file:
        writer = csv.writer(file)
        for i in range(len(samples)):
            writer.writerow(samples[i])


if __name__ == "__main__":
    main()
# Out:
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 0
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 1
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 2
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 3
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 5
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 6
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 7
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 8
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 9
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 10
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 11
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 12
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 13
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 14
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 15
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 16
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 17
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 18
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 19
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 20
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 21
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 22
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 23
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 24
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 25
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 26
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 27
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 28
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 29
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 30
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 31
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 32
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 33
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 34
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 35
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 36
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 37
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 38
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 39
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 40
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 41
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 42
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 43
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 44
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 45
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 46
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 47
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 48
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 49
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 50
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 51
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 52
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 53
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 54
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 55
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 56
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 57
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 58
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 59
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 60
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 61
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 62
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 63
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 64
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 65
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 66
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 67
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 68
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 69
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 70
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 71
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 72
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 73
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 74
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 75
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 76
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 77
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 78
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 79
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 80
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 81
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 82
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 83
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 84
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 85
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 86
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 87
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 88
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 89
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 90
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 91
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 92
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 93
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 94
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 95
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 96
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 97
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 98
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 99
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 100
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 101
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 102
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 103
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 104
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 105
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 106
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 107
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 108
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 109
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 110
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 111
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 112
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 113
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 114
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 115
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 116
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 117
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 118
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 119
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 120
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 121
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 122
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 123
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 124
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 125
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 126
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 127
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 128
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 129
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 130
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 131
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 132
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 133
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 134
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 135
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 136
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 137
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 138
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 139
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 140
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 141
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 142
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 143
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 144
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 145
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 146
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 147
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 148
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 149
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 150
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 151
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 152
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 153
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 154
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 155
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 156
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 157
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 158
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 159
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 160
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 161
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 162
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 163
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 164
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 165
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 166
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 167
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 168
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 169
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 170
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 171
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 172
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 173
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 174
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 175
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 176
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 177
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 178
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 179
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 180
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 181
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 182
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 183
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 184
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 185
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 186
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 187
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 188
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 189
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 190
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 191
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 192
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 193
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 194
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 195
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 196
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 197
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 198
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 199
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 200
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 201
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 202
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 203
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 204
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 205
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 206
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 207
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 208
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 209
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 210
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 211
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 212
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 213
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 214
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 215
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 216
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 217
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 218
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 219
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 220
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 221
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 222
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 223
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 224
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 225
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 226
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 227
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 228
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 229
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 230
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 231
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 232
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 233
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 234
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 235
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 236
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 237
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 238
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 239
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 240
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 241
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 242
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 243
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 244
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 245
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 246
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 247
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 248
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 249
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 250
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 251
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 252
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 253
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 254
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 255
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 256
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 257
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 258
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 259
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 260
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 261
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 262
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 263
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 264
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 265
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 266
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 267
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 268
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 269
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 270
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 271
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 272
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 273
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 274
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 275
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 276
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 277
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 278
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 279
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 280
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 281
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 282
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 283
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 284
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 285
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 286
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 287
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 288
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 289
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 290
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 291
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 292
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 293
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 294
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 295
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 296
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 297
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 298
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 299
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 300
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 301
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 302
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 303
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 304
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 305
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 306
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 307
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 308
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 309
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 310
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 311
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 312
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 313
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 314
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 315
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 316
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 317
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 318
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 319
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 320
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 321
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 322
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 323
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 324
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 325
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 326
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 327
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 328
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 329
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 330
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 331
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 332
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 333
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 334
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 335
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 336
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 337
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 338
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 339
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 340
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 341
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 342
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 343
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 344
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 345
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 346
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 347
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 348
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 349
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 350
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 351
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 352
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 353
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 354
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 355
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 356
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 357
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 358
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 359
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 360
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 361
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 362
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 363
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 364
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 365
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 366
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 367
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 368
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 369
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 370
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 371
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 372
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 373
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 374
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 375
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 376
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 377
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 378
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 379
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 380
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 381
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 382
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 383
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 384
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 385
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 386
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 387
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 388
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 389
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 390
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 391
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 392
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 393
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 394
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 395
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 396
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 397
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 398
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 399
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 400
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 401
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 402
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 403
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 404
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 405
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 406
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 407
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 408
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 409
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 410
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 411
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 412
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 413
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 414
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 415
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 416
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 417
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 418
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 419
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 420
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 421
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 422
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 423
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 424
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 425
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 426
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 427
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 428
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 429
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 430
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 431
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 432
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 433
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 434
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 435
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 436
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 437
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 438
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 439
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 440
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 441
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 442
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 443
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 444
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 445
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 446
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 447
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 448
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 449
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 450
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 451
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 452
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 453
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 454
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 455
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 456
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 457
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 458
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 459
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 460
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 461
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 462
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 463
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 464
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 465
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 466
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 467
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 468
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 469
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 470
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 471
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 472
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 473
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 474
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 475
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 476
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 477
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 478
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 479
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 480
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 481
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 482
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 483
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 484
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 485
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 486
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 487
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 488
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 489
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 490
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 491
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 492
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 493
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 494
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 495
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 496
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 497
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 498
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 499
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 500
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 501
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 502
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 503
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 504
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 505
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 506
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 507
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 508
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 509
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 510
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 511
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 512
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 513
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 514
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 515
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 516
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 517
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 518
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 519
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 520
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 521
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 522
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 523
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 524
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 525
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 526
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 527
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 528
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 529
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 530
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 531
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 532
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 533
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 534
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 535
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 536
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 537
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 538
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 539
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 540
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 541
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 542
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 543
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 544
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 545
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 546
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 547
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 548
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 549
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 550
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 551
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 552
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 553
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 554
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 555
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 556
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 557
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 558
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 559
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 560
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 561
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 562
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 563
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 564
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 565
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 566
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 567
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 568
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 569
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 570
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 571
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 572
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 573
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 574
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 575
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 576
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 577
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 578
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 579
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 580
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 581
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 582
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 583
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 584
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 585
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 586
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 587
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 588
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 589
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 590
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 591
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 592
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 593
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 594
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 595
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 596
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 597
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 598
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 599
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 600
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 601
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 602
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 603
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 604
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 605
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 606
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 607
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 608
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 609
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 610
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 611
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 612
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 613
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 614
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 615
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 616
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 617
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 618
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 619
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 620
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 621
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 622
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 623
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 624
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 625
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 626
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 627
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 628
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 629
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 630
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 631
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 632
# ...
# Simulation completed for 4792
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4793
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4794
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4795
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4796
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4797
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4798
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4799
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4800
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4801
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4802
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4803
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4804
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4805
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4806
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4807
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4808
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4809
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4810
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4811
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4812
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4813
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4814
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4815
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4816
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4817
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4818
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4819
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4820
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4821
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4822
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4823
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4824
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4825
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4826
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4827
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4828
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4829
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4830
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4831
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4832
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4833
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4834
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4835
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4836
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4837
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4838
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4839
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4840
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4841
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4842
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4843
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4844
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4845
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4846
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4847
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4848
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4849
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4850
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4851
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4852
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4853
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4854
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4855
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4856
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4857
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4858
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4859
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4860
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4861
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4862
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4863
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4864
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4865
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4866
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4867
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4868
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4869
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4870
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4871
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4872
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4873
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4874
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4875
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4876
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4877
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4878
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4879
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4880
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4881
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4882
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4883
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4884
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4885
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4886
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4887
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4888
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4889
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4890
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4891
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4892
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4893
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4894
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4895
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4896
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4897
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4898
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4899
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4900
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4901
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4902
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4903
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4904
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4905
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4906
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4907
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4908
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4909
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4910
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4911
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4912
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4913
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4914
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4915
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4916
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4917
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4918
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4919
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4920
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4921
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4922
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4923
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4924
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4925
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4926
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4927
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4928
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4929
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4930
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4931
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4932
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4933
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4934
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4935
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4936
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4937
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4938
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4939
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4940
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4941
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4942
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4943
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4944
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4945
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4946
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4947
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4948
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4949
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4950
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4951
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4952
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4953
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4954
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4955
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4956
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4957
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4958
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4959
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4960
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4961
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4962
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4963
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4964
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4965
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4966
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4967
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4968
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4969
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4970
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4971
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4972
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4973
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4974
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4975
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4976
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4977
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4978
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4979
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4980
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4981
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4982
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4983
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4984
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4985
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4986
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4987
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4988
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4989
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4990
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4991
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4992
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4993
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4994
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4995
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4996
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4997
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4998
# Adjusted dt for stability. New value dt=0.0025
# Simulation completed for 4999
